# %% [markdown]
# # IBM Data Scientist Certification Capstone
# #### By Arash
# ##### Apr 2020

# %%
# All needed libraries will be imprted here

# importing Pandas and Numpy
import pandas as pd
import numpy as np

# importing Beautiful Soup
import requests
import csv

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ##### Getting Data from URL

# %%
# Using request.get to retrive data
wikiURL = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %% [markdown]
# ##### Retriving the table using attrs attribute

# %%
data = pd.read_html(wikiURL, header=0, attrs={"class":"wikitable sortable"})[0]
data
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# ...

# %% [markdown]
# ###### Changing the column name

# %%
data.rename(columns={'Postal code': 'PostalCode'}, inplace=True)
data
# Out:
#     PostalCode           Borough  \
# 0          M1A      Not assigned
# 1          M2A      Not assigned
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# ..         ...               ...
# 175        M5Z      Not assigned
# 176        M6Z      Not assigned
# 177        M7Z      Not assigned
# 178        M8Z         Etobicoke
# 179        M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# ...

# %% [markdown]
# ###### Ignoring cells that the 'Borough' column is 'Not Assigned'

# %%
# Droping the 'Not assigned' values from 'Boruogh' colloumn
data = data.drop(data.index[data['Borough']=='Not assigned'])
data.reset_index(drop=True, inplace=True)
data
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park / Harbourfront
# 3                    Lawrence Manor / Lawrence Heights
# 4         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway / Montgomery Road / Old Mill North
# 99                                Church and Wellesley
# 100              Business reply mail Processing CentrE
# ...

# %% [markdown]
# ##### Replace cells that have Neighborhood values Not assigned with Borough value

# %%
data.loc[data['Neighborhood'] =='Not assigned' , 'Neighborhood'] = data['Borough']
data
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park / Harbourfront
# 3                    Lawrence Manor / Lawrence Heights
# 4         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway / Montgomery Road / Old Mill North
# 99                                Church and Wellesley
# 100              Business reply mail Processing CentrE
# ...

# %% [markdown]
# #### Changing the value of '/' to ','

# %%
data['Neighborhood']=data['Neighborhood'].str.replace(u" / ",", ")
data
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100              Business reply mail Processing CentrE
# ...

# %% [markdown]
# Shape of the data frame

# %%
data.shape
# Out:
# (103, 3)

# %% [markdown]
# Saving the dataframe to csv file

# %%
data.to_csv('file_name.csv', index=False)
